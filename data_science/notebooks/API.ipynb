# %%
from roboflow import Roboflow
rf = Roboflow(api_key="CfVGS82wt63mHysL62v4")
project = rf.workspace("mnt-bgmps").project("deteksi-stunting-jj1oq")
version = project.version(1)
dataset = version.download("multiclass")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Deteksi-Stunting-1 to multiclass:: 100%|██████████| 4086/4086 [00:06<00:00, 622.35it/s]
# Extracting Dataset Version Zip to Deteksi-Stunting-1 in multiclass:: 100%|██████████| 1861/1861 [00:00<00:00, 2866.16it/s]
